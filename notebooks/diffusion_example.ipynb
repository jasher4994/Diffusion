# %%
from diffusers import StableDiffusionPipeline
import torch
# Required to go to /home/azureuser/Diffusion/.venv/lib/python3.10/site-packages/diffusers/utils/dynamic_modules_utils.py
# and delete import of cached download.

# %%
model_id = "sd-legacy/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id) # torch_dtype=torch.float16 if RAM requires.
pipe = pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt = "Book coover, health guide, title: war of the wizards"
image = pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
